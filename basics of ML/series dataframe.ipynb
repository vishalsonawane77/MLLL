# %%
import pandas as pd 
import numpy as np

# %%
name = {1:'Vishal',2:'Dipak',3:'Ashwin',4:'Shubham'}
surname = {1:'Sonawane',2:'Thorat',3:'Mahajan',4:'Chaudhari'}

# %%
a = pd.DataFrame({'Name':name,'Surname':surname})
a
# Out:
#       Name    Surname
# 1   Vishal   Sonawane
# 2    Dipak     Thorat
# 3   Ashwin    Mahajan
# 4  Shubham  Chaudhari

# %%
a = {'a':[10,20,30,40],'b':[11,21,31,41],'c':[12,22,32,42],'d':[13,23,33,43]}
a
# Out:
# {'a': [10, 20, 30, 40],
#  'b': [11, 21, 31, 41],
#  'c': [12, 22, 32, 42],
#  'd': [13, 23, 33, 43]}

# %%
b = pd.DataFrame(a)
b
# Out:
#     a   b   c   d
# 0  10  11  12  13
# 1  20  21  22  23
# 2  30  31  32  33
# 3  40  41  42  43

# %%
d = [{'a':i,'b':i*2,'c':i**2} for i in range(5)]
d
# Out:
# [{'a': 0, 'b': 0, 'c': 0},
#  {'a': 1, 'b': 2, 'c': 1},
#  {'a': 2, 'b': 4, 'c': 4},
#  {'a': 3, 'b': 6, 'c': 9},
#  {'a': 4, 'b': 8, 'c': 16}]

# %%
data = pd.DataFrame(d)
data
# Out:
#    a  b   c
# 0  0  0   0
# 1  1  2   1
# 2  2  4   4
# 3  3  6   9
# 4  4  8  16

# %%
print("hello world")
# Out:
# hello world

# %%
df = pd.read_csv("CarPrice.csv")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration
# 0         1          3        alfa-romero giulia      gas        std  \
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...
# ...

# %%
data=df.dropna()
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration
# 0         1          3        alfa-romero giulia      gas        std  \
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
mask = df['fueltype']=='diesel'
data[mask]
# Out:
#      car_ID  symboling                    CarName fueltype aspiration
# 63       64          0           mazda glc deluxe   diesel        std  \
# 66       67          0              mazda rx-7 gs   diesel        std
# 67       68         -1   buick electra 225 custom   diesel      turbo
# 68       69         -1   buick century luxus (sw)   diesel      turbo
# 69       70          0              buick century   diesel      turbo
# 70       71         -1              buick skyhawk   diesel      turbo
# 90       91          1                nissan gt-r   diesel        std
# 108     109          0                peugeot 304   diesel      turbo
# 110     111          0                peugeot 504   diesel      turbo
# 112     113          0              peugeot 604sl   diesel      turbo
# 114     115          0  peugeot 505s turbo diesel   diesel      turbo
# 116     117          0                peugeot 504   diesel      turbo
# ...

# %%
data[mask].shape[0]
# Out:
# 20

# %%
df.iloc[:,[2,3,6]]
# Out:
#                       CarName fueltype      carbody
# 0          alfa-romero giulia      gas  convertible
# 1         alfa-romero stelvio      gas  convertible
# 2    alfa-romero Quadrifoglio      gas    hatchback
# 3                 audi 100 ls      gas        sedan
# 4                  audi 100ls      gas        sedan
# ..                        ...      ...          ...
# 200           volvo 145e (sw)      gas        sedan
# 201               volvo 144ea      gas        sedan
# 202               volvo 244dl      gas        sedan
# 203                 volvo 246   diesel        sedan
# 204               volvo 264gl      gas        sedan
#
# [205 rows x 3 columns]
