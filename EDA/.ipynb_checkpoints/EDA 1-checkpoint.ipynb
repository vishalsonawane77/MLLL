# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Categorica Data

# %% [markdown]
# ## a. Bar Graphs

# %%
sns.countplot(x='Survived',data=df,hue ="Pclass")
#df['Survived'].value_counts()
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',data=df,hue='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',data=df,hue ="Sex")
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(hue='Embarked',x='Embarked',data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# ## b. Pie Chart

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numeric Data

# %% [markdown]
# ## a. Histogram

# %%
plt.hist(df.Age,bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ## b. Distplot

# %%
sns.histplot(df.Age,kde=True,stat="density",bins=8)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(y=df.Age,data=df,color='g')
# Out:
# <Axes: ylabel='Age'>

# %% [raw]
# df.Age.min()

# %%
df.Age.max()
# Out:
# 80.0

# %%
sns.boxplot(y=df.Age,x='Sex',data=df,hue='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(y=df.Age,x=df.Pclass,hue='Pclass',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
